# %% [markdown]
# # ds-101 Test Notebook
# A quick sanity check to confirm Python and Jupyter are working.

# %%
import sys
print(f'Python version: {sys.version}')
# Out:
# Python version: 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]

# %%
nums = [1, 2, 3, 4, 5]
total = sum(nums)
average = total / len(nums)
print(f'Numbers: {nums}')
print(f'Sum: {total}, Average: {average}')
# Out:
# Numbers: [1, 2, 3, 4, 5]
# Sum: 15, Average: 3.0

# %%
squares = {x: x**2 for x in range(1, 6)}
for num, sq in squares.items():
    print(f'{num}^2 = {sq}')
# Out:
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25
